# %%
import pandas as pd
import os
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import MinMaxScaler,OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
import xgboost as xgb

# %%
df=pd.read_csv("CouponAcceptance.csv")
df=df.drop(columns="car")
df.dropna(subset=["Accept(Y/N?)"], inplace=True) # Drop rows where target is NaN
x=df.drop(columns="Accept(Y/N?)",axis=1)
y=df["Accept(Y/N?)"]
num_col=x.select_dtypes(exclude=object).columns
cat_col=x.select_dtypes(include=object).columns

# %%
num_pipe=Pipeline(steps=[
    ("imputer",SimpleImputer(strategy="median")),
    ("scaler",MinMaxScaler())
])

# %%
cat_pipe=Pipeline(steps=[
    ("imputer",SimpleImputer(strategy="most_frequent")),
    ("scaler",OneHotEncoder(drop="first",handle_unknown="ignore"))
])

# %%
preprocessor=ColumnTransformer([
    ("num",num_pipe,num_col),
    ("cat",cat_pipe,cat_col)
])

# %%
#Decision Tree Classifier
dtc=Pipeline(steps=[
("preprocessor" , preprocessor),
("tree",DecisionTreeClassifier(random_state=42))
])

# %%
# Random Forest Classifier
rfc=Pipeline(steps=[
("preprocessor" , preprocessor),
("forest",RandomForestClassifier(random_state=42))
])

# %%
# Logistic Regression
lr=Pipeline(steps=[
("preprocessor" , preprocessor),
("logistic",LogisticRegression(random_state=42))
])

# %%
#XGBoost
xg=Pipeline(steps=[
("preprocessor" , preprocessor),
("xgb",xgb.XGBClassifier(random_state=42))
])

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=42)

# %%
dtc.fit(x_train,y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
#                                                                    MinMaxScaler())]),
#                                                   Index(['toCoupon_GEQ5min', 'toCoupon_GEQ15min', 'toCoupon_GEQ25min',
#        'direction_same', 'direction_opp'],
#       dtype='object')),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_frequent')...
#                                                                    OneHotEncoder(drop='first',
# ...

# %%
rfc.fit(x_train,y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
#                                                                    MinMaxScaler())]),
#                                                   Index(['toCoupon_GEQ5min', 'toCoupon_GEQ15min', 'toCoupon_GEQ25min',
#        'direction_same', 'direction_opp'],
#       dtype='object')),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_frequent')...
#                                                                    OneHotEncoder(drop='first',
# ...

# %%
lr.fit(x_train,y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
#                                                                    MinMaxScaler())]),
#                                                   Index(['toCoupon_GEQ5min', 'toCoupon_GEQ15min', 'toCoupon_GEQ25min',
#        'direction_same', 'direction_opp'],
#       dtype='object')),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_frequent')...
#                                                                    OneHotEncoder(drop='first',
# ...

# %%
xg.fit(x_train,y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
#                                                                    MinMaxScaler())]),
#                                                   Index(['toCoupon_GEQ5min', 'toCoupon_GEQ15min', 'toCoupon_GEQ25min',
#        'direction_same', 'direction_opp'],
#       dtype='object')),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_frequent')...
#                                feature_types=None, feature_weights=None,
# ...

# %%
new_df=pd.read_csv("CouponAcceptancePrediction.csv")

# %%
new_df=new_df.drop(columns=["car","Accept(Y/N?)"])

# %%
prediction=dtc.predict(new_df)

# %%
prediction=rfc.predict(new_df)

# %%
prediction=lr.predict(new_df)

# %%
prediction=xg.predict(new_df)

# %%
new_df["predict"]=prediction

# %%
new_df.to_csv("output_DTC.csv",index=False)

# %%
new_df.to_csv("output_RFC.csv",index=False)

# %%
new_df.to_csv("output_LR.csv",index=False)

# %%
new_df.to_csv("output_XG.csv",index=False)
